# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DAT101x/Lemonade.csv")
print(df)
# Out:
#            Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0    01/01/2017     Sunday         27.0      2.00      15    0.3     10
# 1    02/01/2017     Monday         28.9      1.33      15    0.3     13
# 2    03/01/2017    Tuesday         34.5      1.33      27    0.3     15
# 3    04/01/2017  Wednesday         44.1      1.05      28    0.3     17
# 4    05/01/2017   Thursday         42.4      1.00      33    0.3     18
# ..          ...        ...          ...       ...     ...    ...    ...
# 360  27/12/2017  Wednesday         42.7      1.00      33    0.3     19
# 361  28/12/2017   Thursday         37.8      1.25      32    0.3     16
# 362  29/12/2017     Friday         39.5      1.25      17    0.3     15
# 363  30/12/2017   Saturday         30.9      1.43      22    0.3     13
# 364  31/12/2017     Sunday         15.1      2.50       9    0.3      7
#
# [365 rows x 7 columns]

# %%
print("Max Sales is : ",df['Sales'].max())
print("Min Sales is : ",df['Sales'].min())
# Out:
# Max Sales is :  43
# Min Sales is :  7

# %%
# find the date where rainfall is highest and lowest
df[["Sales", "Rainfall"]].groupby(["Rainfall"]).describe()
# Out:
#          Sales
#          count       mean       std   min    25%   50%    75%   max
# Rainfall
# 0.47       7.0  41.857143  0.899735  41.0  41.00  42.0  42.50  43.0
# 0.49       1.0  40.000000       NaN  40.0  40.00  40.0  40.00  40.0
# 0.50       3.0  39.666667  0.577350  39.0  39.50  40.0  40.00  40.0
# 0.51       6.0  37.833333  0.752773  37.0  37.25  38.0  38.00  39.0
# 0.53       2.0  37.000000  1.414214  36.0  36.50  37.0  37.50  38.0
# 0.54       6.0  35.333333  0.816497  35.0  35.00  35.0  35.00  37.0
# 0.56       7.0  35.142857  0.899735  34.0  34.50  35.0  36.00  36.0
# 0.57      10.0  34.300000  0.948683  33.0  33.25  35.0  35.00  35.0
# 0.59      12.0  32.750000  0.866025  32.0  32.00  32.5  33.25  34.0
# 0.61       8.0  32.000000  0.755929  31.0  31.75  32.0  32.25  33.0
# 0.63      19.0  30.842105  0.764719  30.0  30.00  31.0  31.00  32.0
# 0.65      17.0  29.882353  0.927520  29.0  29.00  30.0  31.00  31.0
# ...

# %%
df[df.Rainfall ==df.Rainfall.max()]
# Out:
#            Date     Day  Temperature  Rainfall  Flyers  Price  Sales
# 364  31/12/2017  Sunday         15.1       2.5       9    0.3      7

# %%
df[df.Sales ==df.Sales.max()]
# Out:
#            Date       Day  Temperature  Rainfall  Flyers  Price  Sales
# 181  01/07/2017  Saturday        102.9      0.47      59    0.5     43
# 207  27/07/2017  Thursday         97.9      0.47      74    0.5     43

# %%
#we can find correlation between temperature and sales
df['Temperature'].corr(df['Sales'])
# Out:
# 0.9898320849779698

# %%
# correlation between Flyers and Sales
df['Flyers'].corr(df['Sales'])
# Out:
# 0.8051825759184937

# %%
#use scatter plot to see relationship between temparture and sales
plt.xlabel('Temperature')
plt.ylabel('Sales')
plt.grid()
plt.scatter(df['Temperature'],df['Sales'])
plt.show()

# %%
plt.hist(df['Sales'],bins=50
        )
# Out:
# (array([ 1.,  0.,  0.,  0.,  2.,  2.,  4.,  0.,  9.,  8.,  0., 10.,  6.,
#         11.,  0., 12., 16.,  0., 11., 10., 10.,  0., 18., 24.,  0., 35.,
#         22., 19.,  0., 14., 23., 18.,  0., 16., 14.,  0.,  8.,  6., 13.,
#          0.,  4.,  3.,  0.,  4.,  2.,  3.,  0.,  3.,  2.,  2.]),
#  array([ 7.  ,  7.72,  8.44,  9.16,  9.88, 10.6 , 11.32, 12.04, 12.76,
#         13.48, 14.2 , 14.92, 15.64, 16.36, 17.08, 17.8 , 18.52, 19.24,
#         19.96, 20.68, 21.4 , 22.12, 22.84, 23.56, 24.28, 25.  , 25.72,
#         26.44, 27.16, 27.88, 28.6 , 29.32, 30.04, 30.76, 31.48, 32.2 ,
#         32.92, 33.64, 34.36, 35.08, 35.8 , 36.52, 37.24, 37.96, 38.68,
#         39.4 , 40.12, 40.84, 41.56, 42.28, 43.  ]),
#  <a list of 50 Patch objects>)

# %%
import seaborn as sns

# %%
g = sns.jointplot("Sales", "Temperature", data=df, kind="reg")
